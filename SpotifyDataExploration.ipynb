# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
#Authentication - without user
c_id="f16ddcb0cf774681a532b82f47761355"
c_secret="316c4e03c921403bb4951add2b473416"
client_credentials_manager = SpotifyClientCredentials(client_id=c_id, client_secret=c_secret)
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/playlist/37i9dQZEVXbNG2KDcFcKOF?si=1333723a6eff4b7f"
playlist_URI = playlist_link.split("/")[-1].split("?")[0]
track_uris = [x["track"]["uri"] for x in sp.playlist_tracks(playlist_URI)["items"]]

# %%
for track in sp.playlist_tracks(playlist_URI)["items"]:
    #URI
    track_uri = track["track"]["uri"]
    print(track_uri)

    #Track name
    track_name = track["track"]["name"]
    print(track_name)

    #Main Artist
    artist_uri = track["track"]["artists"][0]["uri"]
    artist_info = sp.artist(artist_uri)
    print(artist_uri)

    #Name, popularity, genre
    artist_name = track["track"]["artists"][0]["name"]
    artist_pop = artist_info["popularity"]
    artist_genres = artist_info["genres"]
    print(artist_name)

    #Album
    album = track["track"]["album"]["name"]
    
    #Popularity of the track
    track_pop = track["track"]["popularity"]
    print("")
# Out:
# spotify:track:4Dvkj6JhhA12EX05fT7y2e
# As It Was
# spotify:artist:6KImCVD70vtIoJWnq6nGn3
# Harry Styles
#
# spotify:track:75FEaRjZTKLhTrFGsfMUXR
# Running Up That Hill (A Deal With God)
# spotify:artist:1aSxMhuvixZ8h9dK9jIDwL
# Kate Bush
#
# spotify:track:6Sq7ltF9Qa7SNFBsV5Cogx
# Me Porto Bonito
# spotify:artist:4q3ewBCX7sLwd24euuV69X
# Bad Bunny
#
# spotify:track:6xGruZOHLs39ZbVccQTuPZ
# Glimpse of Us
# spotify:artist:3MZsBdqDrRTJihTHQrO6Dq
# Joji
#
# spotify:track:3k3NWokhRRkEPhCzPmV8TW
# Ojitos Lindos
# spotify:artist:4q3ewBCX7sLwd24euuV69X
# Bad Bunny
#
# spotify:track:1IHWl5LamUGEuP4ozKQSXZ
# Tití Me Preguntó
# spotify:artist:4q3ewBCX7sLwd24euuV69X
# Bad Bunny
#
# spotify:track:10SRMwb9EuVS1K9rYsBfHQ
# Yet To Come
# spotify:artist:3Nrfpe0tUJi4K4DXYWgMUX
# BTS
#
# spotify:track:6Xom58OOXk2SoU711L2IXO
# Moscow Mule
# spotify:artist:4q3ewBCX7sLwd24euuV69X
# Bad Bunny
#
# spotify:track:5Eax0qFko2dh7Rl2lYs3bx
# Efecto
# spotify:artist:4q3ewBCX7sLwd24euuV69X
# Bad Bunny
#
# spotify:track:7dSZ6zGTQx66c2GF91xCrb
# PROVENZA
# spotify:artist:790FomKkXshlbRYZFtlgla
# KAROL G
#
# spotify:track:69xohKu8C1fsflYAiSNbwM
# Run BTS
# spotify:artist:3Nrfpe0tUJi4K4DXYWgMUX
# BTS
#
# spotify:track:1PckUlxKqWQs3RlWXVBLw3
# About Damn Time
# spotify:artist:56oDRnqbIiwx4mymNEv7dS
# Lizzo
#
# spotify:track:02MWAaffLxlfxAUY7c5dvx
# Heat Waves
# spotify:artist:4yvcSjfu4PC0CYQyLy4wSq
# Glass Animals
#
# spotify:track:2rurDawMfoKP4uHyb2kJBt
# Te Felicito
# spotify:artist:0EmeFodog0BfCgMzAIvKQp
# Shakira
#
# spotify:track:4tYFy8ALRjIZvnvSLw5lxN
# Party
# spotify:artist:4q3ewBCX7sLwd24euuV69X
# Bad Bunny
#
# spotify:track:1qEmFfgcLObUfQm0j1W2CK
# Late Night Talking
# spotify:artist:6KImCVD70vtIoJWnq6nGn3
# Harry Styles
#
# spotify:track:0wHFktze2PHC5jDt3B17DC
# First Class
# spotify:artist:2LIk90788K0zvyj2JJVwkJ
# Jack Harlow
#
# spotify:track:5PjdY0CKGZdEuoNab3yDmX
# STAY (with Justin Bieber)
# spotify:artist:2tIP7SsRs7vjIcLrU85W8J
# The Kid LAROI
#
# spotify:track:2DB4DdfCFMw1iaR6JaR03a
# Bam Bam (feat. Ed Sheeran)
# spotify:artist:4nDoRrQiYLoBzwC5BhVJzF
# Camila Cabello
#
# spotify:track:0O6u0VJ46W86TxN9wgyqDj
# I Like You (A Happier Song) (with Doja Cat)
# spotify:artist:246dkjvS1zLTtiykXe5h60
# Post Malone
#
# spotify:track:41oY4WCTj5kccfesTVFnvN
# Tarot
# spotify:artist:4q3ewBCX7sLwd24euuV69X
# Bad Bunny
#
# spotify:track
otify:artist:6eUKZXaKkcviH0Ku9w2n3V
# Ed Sheeran
#
# spotify:track:3uUuGVFu1V7jTQL60S1r8z
# Where Are You Now
# spotify:artist:7f5Zgnp2spUuuzKplmRkt7
# Lost Frequencies
#
# spotify:track:59nOXPmaKlBfGMDeOVGrIK
# WAIT FOR U (feat. Drake & Tems)
# spotify:artist:1RyvyyTE3xzB2ZywiAwp0i
# Future
#
# spotify:track:5LYMamLv12UPbemOaTPyeV
# Music For a Sushi Restaurant
# spotify:artist:6KImCVD70vtIoJWnq6nGn3
# Harry Styles
#
# spotify:track:6mmPpaltUZK7xjNlBPQQ0p
# Desesperados
# spotify:artist:1mcTU81TzQhprhouKaTkpq
# Rauw Alejandro
#
# spotify:track:1797zYiX4cKosMH836X9Gt
# La Corriente
# spotify:artist:4q3ewBCX7sLwd24euuV69X
# Bad Bunny
#
# spotify:track:0OTNHGKcqQbk51bOYe462Y
# ULTRA SOLO
# spotify:artist:768O5GliF0bqscyghggrbE
# Polimá Westcoast
#
# spotify:track:1IthE5GNiRzFN5CVaCa445
# Born Singer
# spotify:artist:3Nrfpe0tUJi4K4DXYWgMUX
# BTS
#
# spotify:track:6uvh0In7u1Xn4HgxOfAn8O
# Matilda
# spotify:artist:6KImCVD70vtIoJWnq6nGn3
# Harry Styles
#
# spotify:track:31i56LZnwE6uSu3exoHjtB
# Neverita
# spotify:artist:4q3ewBCX7sLwd24euuV69X
# Bad Bunny
#
# spotify:track:5kVZxyMY1gfdCLiChsfjn1
# Yo No Soy Celoso
# spotify:artist:4q3ewBCX7sLwd24euuV69X
# Bad Bunny
#
# spotify:track:2QjOHCTQ1Jl3zawyYOpxh6
# Sweater Weather
# spotify:artist:77SW9BnxLY8rJ0RciFqkHh
# The Neighbourhood
#
# spotify:track:0VjIjW4GlUZAMYd2vXMi3b
# Blinding Lights
# spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ
# The Weeknd
#
# spotify:track:51Zw1cKDgkad0CXv23HCMU
# Daylight
# spotify:artist:6KImCVD70vtIoJWnq6nGn3
# Harry Styles
#
# spotify:track:3FkeNbs9Zeiqkr3WkbOiGp
# Envolver
# spotify:artist:7FNnA9vBm6EKceENgCGRMb
# Anitta

# %%
sp.audio_features(track_uri)[0]
# Out:
# {'danceability': 0.812,
#  'energy': 0.736,
#  'key': 4,
#  'loudness': -5.421,
#  'mode': 0,
#  'speechiness': 0.0833,
#  'acousticness': 0.152,
#  'instrumentalness': 0.00254,
#  'liveness': 0.0914,
#  'valence': 0.396,
#  'tempo': 91.993,
#  'type': 'audio_features',
#  'id': '3FkeNbs9Zeiqkr3WkbOiGp',
#  'uri': 'spotify:track:3FkeNbs9Zeiqkr3WkbOiGp',
#  'track_href': 'https://api.spotify.com/v1/tracks/3FkeNbs9Zeiqkr3WkbOiGp',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3FkeNbs9Zeiqkr3WkbOiGp',
#  'duration_ms': 193806,
#  'time_signature': 4}
